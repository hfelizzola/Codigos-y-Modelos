# %% [markdown]
# # Contratos de obra

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
pd.set_option('display.max_columns',None)

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
os.chdir('/gdrive/MyDrive/Colab Notebooks/Proyecto Riesgo Corrupción')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-1ed87300a8d8> in <cell line: 1>()
# ----> 1 os.chdir('/gdrive/MyDrive/Colab Notebooks/Proyecto Riesgo Corrupción')
#
# NameError: name 'os' is not defined

# %%
df = pd.read_excel('obra/secop_i_obra_sanciones.xlsx')
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-e4f1118ef4ec> in <cell line: 1>()
# ----> 1 df = pd.read_excel('obra/secop_i_obra_sanciones.xlsx')
#       2 df.head()
#
# NameError: name 'pd' is not defined
